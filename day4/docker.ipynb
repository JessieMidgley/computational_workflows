# %% [markdown]
# # A short introduction to containerized software
#
# After spending using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    27.2.0
#  Context:    desktop-linux
#  Debug Mode: false
#  Plugins:
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.16.2-desktop.1
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-buildx
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.29.2-desktop.2
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-compose
#   debug: Get a shell into any image or container (Docker Inc.)
#     Version:  0.0.34
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-debug
#   desktop: Docker Desktop commands (Alpha) (Docker Inc.)
#     Version:  v0.0.15
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-desktop
#   dev: Docker Dev Environments (Docker Inc.)
#     Version:  v0.1.2
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-dev
#   extension: Manages Docker extensions (Docker Inc.)
#     Version:  v0.2.25
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-extension
#   feedback: Provide feedback, right in your terminal! (Docker Inc.)
#     Version:  v1.0.5
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-feedback
#   init: Creates Docker-related starter files for your project (Docker Inc.)
#     Version:  v1.3.0
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-init
#   sbom: View the packaged-based Software Bill Of Materials (SBOM) for an image (Anchore Inc.)
#     Version:  0.6.0
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-sbom
#   scout: Docker Scout (Docker Inc.)
#     Version:  v1.13.0
#     Path:     /Users/Jessie/.docker/cli-plugins/docker-scout
#
# Server:
#  Containers: 0
#   Running: 0
#   Paused: 0
#   Stopped: 0
#  Images: 12
#  Server Version: 27.2.0
#  Storage Driver: overlay2
#   Backing Filesystem: extfs
#   Supports d_type: true
#   Using metacopy: false
#   Native Overlay Diff: true
#   userxattr: false
#  Logging Driver: json-file
#  Cgroup Driver: cgroupfs
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 8fc6bcff51318944179630522a095cc9dbf9f353
#  runc version: v1.1.13-0-g58aa920
#  init version: de40ad0
#  Security Options:
#   seccomp
#    Profile: unconfined
#   cgroupns
#  Kernel Version: 6.10.4-linuxkit
#  Operating System: Docker Desktop
#  OSType: linux
#  Architecture: aarch64
#  CPUs: 8
#  Total Memory: 3.829GiB
#  Name: docker-desktop
#  ID: 4ba6d86f-0cb9-45ef-9ba7-62bf95ffb0b6
#  Docker Root Dir: /var/lib/docker
#  Debug Mode: false
#  HTTP Proxy: http.docker.internal:3128
#  HTTPS Proxy: http.docker.internal:3128
#  No Proxy: hubproxy.docker.internal
#  Labels:
#   com.docker.desktop.address=unix:///Users/Jessie/Library/Containers/com.docker.docker/Data/docker-cli.sock
#  Experimental: false
#  Insecure Registries:
#   hubproxy.docker.internal:5555
#   127.0.0.0/8
#  Live Restore Enabled: false
#
# WARNING: daemon is not using the default seccomp profile

# %% [markdown]
# ### What is a container?

# %% [markdown]
# It is a standard software unit that packages up code with all its dependencies so that the program runs the same on any OS. The container includes all code, libraries, settings, etc. needed to run an application.

# %% [markdown]
# ### Why do we use containers?

# %% [markdown]
# The containers include everything needed to run an application and ensure that the application runs quickly and reliably on any computing environment.

# %% [markdown]
# ### What is a docker image?

# %% [markdown]
# It is an executable file that is used to create the Docker container. It includes all of the files, binaries, libraries, and configurations to run a container.

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %% [markdown]
# cf1e890891187e7636d49bcd3120af3530a08cc53a1ac01b630a9ee9495e8c42

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm /cf1e890891187e7636d49bcd3120af3530a08cc53a1ac01b630a9ee9495e8c42
# Out:
# /cf1e890891187e7636d49bcd3120af3530a08cc53a1ac01b630a9ee9495e8c42

# %%
# !docker logs cf1e890891187e7636d49bcd3120af3530a08cc53a1ac01b630a9ee9495e8c42
# Out:
# Error response from daemon: No such container: cf1e890891187e7636d49bcd3120af3530a08cc53a1ac01b630a9ee9495e8c42

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. downloaded and expanded fastqc_v0.12.1.zip
# 2. run chmod +x fastqc to make the file executable
# 3. added fastqc to my path (/usr/local/bin/fastqc)
# 4. ran fastqc SRX19144488_SRR23195511_1.fastq.gz
# ...

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0
# Out:
# 0.12.1--d3caca66b4f3d3b0: Pulling from library/fastqc
#
# 4a5e885d: Pulling fs layer
# f7ad9b3c: Pulling fs layer
# f16d8faf: Pulling fs layer
# b700ef54: Pulling fs layer
# 8fb245f5: Pulling fs layer
# 96a0b3ed: Pulling fs layer
# 21e027fa: Pulling fs layer
# 98df307d: Pulling fs layer
# 81345b94: Pulling fs layer
# 89cafbe9: Pulling fs layer
# 98df307d: Waiting fs layer
# 81345b94: Waiting fs layer
# 7c3c4e61: Pull complete 361MB/361MBBBBDigest: sha256:ac39a0c379226c3b1c3b1c0e59defae369804dbb5b2339344308d1e0b82506ec
# Status: Downloaded newer image for community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0
# community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0

# %%
# run the container and save the results to a new "fastqc_results" directory
# !mkdir /Users/Jessie/PycharmProjects/comp_workflows/day4/fastqc_results
# Out:
# mkdir: /Users/Jessie/PycharmProjects/comp_workflows/day4/fastqc_results: File exists

# %%
# !docker tag community.wave.seqera.io/library/fastqc:0.12.1--d3caca66b4f3d3b0 fastqc-image

# %%
# !docker run -v /Users/Jessie/PycharmProjects/comp_workflows/day2/files/fastq:/data -v /Users/Jessie/PycharmProjects/comp_workflows/day4/fastqc_results:/output fastqc-image fastqc /data/SRX19144488_SRR23195511_1.fastq.gz -o /output
# Out:
# application/gzip
# Started analysis of SRX19144488_SRR23195511_1.fastq.gz
# Approx 5% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 10% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 15% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 20% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 25% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 30% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 35% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 40% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 45% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 50% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 55% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 60% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 65% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 70% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 75% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 80% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 85% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 90% complete for SRX19144488_SRR23195511_1.fastq.gz
# Approx 95% complete for SRX19144488_SRR23195511_1.fastq.gz
# Analysis complete for SRX19144488_SRR23195511_1.fastq.gz

# %%
# Alternatively, from the command line, I also tried:
# !docker run --rm -it -v /Users/Jessie/PycharmProjects/comp_workflows/day2/files/fastq:/data fastqc-image
# Out:
# (base) root@a3042d8e9183:/tmp# ^C
#
# (base) root@a3042d8e9183:/tmp# zsh:cd:1: no such file or directory: /data
# Skipping 'SRX19144488_SRR23195511_1.fastq.gz' which didn't exist, or couldn't be read

# %% [markdown]
# ### Now that you know how to use a docker container, which approach between running everything manually and using docker was easier and which approach will be easier in the future?

# %% [markdown]
# Running FastQC manually was easy since I already has the tool installed on my laptop and could simply run the command "fastqc SRX19144486_SRR23195516_1.fastq.gz". With Docker there is a steeper learning curve, so it took me longer since I had to figure out the command to run the correct Docker image with my input file. In the future it would probably be easier to run Docker, especially for tools that I don't already have locally installed.

# %% [markdown]
# ### What would you say, which approach is more reproducible?

# %% [markdown]
# Using the Docker container is more reproducible since everything is containerized and packaged, and therefore the results are independent of my computing environment. The manual installation of FastQC is dependent on my specific OS.

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# For me, both results from the previous analysis (Sham_oxy_2_1.gz) and the Docker run are identical, and the same fastqc version was used for both (version 0.12.1).

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# open the file "my_dockerfile" in a text editor

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# The RUN line first updates the package list to make sure that the latest versions of the packages will be installed. Then it installs curl and cowsay (-y is used to automatically answer "yes" to installation prompts. I also added apt-get clean to clean up the image.
#
# The ENV line is necessary because cowsay will be installed in the /usr/games directory, but this directory isn't included in the default PATH. So unless we add this directory to our PATH, we would have to explicitly provide the full path to cowsay (/usr/games/cowsay) if we wanted to run it. But the ENV line ensures that we can execute the "cowsay" command from any location.

# %%
# build the docker image
# !docker build -t cowsay_image -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.6s (1/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 0.8s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.0s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.1s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.3s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.4s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.4s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.6s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.7s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 1.8s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.8s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.0s (2/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.0s (3/3)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
# [+] Building 2.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e0 0B / 30.08MB  0.1s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 2.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e0 0B / 30.08MB  0.2s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 2.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbe 3.15MB / 30.08MB  0.4s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 2.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbe 3.15MB / 30.08MB  0.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 2.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbe 6.29MB / 30.08MB  0.7s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 2.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbe 7.34MB / 30.08MB  0.8s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbe 8.39MB / 30.08MB  0.9s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 10.49MB / 30.08MB  1.1s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 11.53MB / 30.08MB  1.2s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 12.58MB / 30.08MB  1.3s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 14.68MB / 30.08MB  1.4s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 16.78MB / 30.08MB  1.6s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 3.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 18.87MB / 30.08MB  1.8s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 4.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  1.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 19.92MB / 30.08MB  1.9s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 4.2s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 23.07MB / 30.08MB  2.1s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 4.4s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 26.21MB / 30.08MB  2.3s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 4.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 28.31MB / 30.08MB  2.4s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 4.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
# [+] Building 4.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.1s
# [+] Building 4.8s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.2s
# [+] Building 4.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.3s
# [+] Building 5.0s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.4s
# [+] Building 5.1s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.5s
# [+] Building 5.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.7s
# [+] Building 5.3s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.7s
# [+] Building 5.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.9s
# [+] Building 5.5s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  0.9s
# [+] Building 5.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
# [+] Building 5.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  0.2s
# [+] Building 5.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  0.3s
# [+] Building 6.0s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  0.4s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# [+] Building 6.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  0.5s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# [+] Building 6.3s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  0.6s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
# [+] Building 6.4s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  0.8s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
# [+] Building 6.6s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  1.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 6.8s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-get  1.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main arm64 Packages [7955
#  => => # kB]
# [+] Building 6.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
# ...
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  10.2s
#  => => # Setting up ca-certificates (20210119) ...
#  => => # debconf: unable to initialize frontend: Dialog
#  => => # debconf: (TERM is not set, so the dialog frontend is not usable.)
#  => => # debconf: falling back to frontend: Readline
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 129 added, 0 removed; done.
# [+] Building 16.0s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  10.3s
#  => => # Setting up libperl5.32:arm64 (5.32.1-4+deb11u3) ...
#  => => # Setting up libcurl4:arm64 (7.74.0-1.3+deb11u13) ...
#  => => # Setting up curl (7.74.0-1.3+deb11u13) ...
#  => => # Setting up perl (5.32.1-4+deb11u3) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u11) ...
# [+] Building 16.1s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  10.5s
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u11) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
# [+] Building 16.3s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  10.7s
#  => => # Processing triggers for libc-bin (2.31-13+deb11u11) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
#  => => # done.
# [+] Building 16.4s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  10.8s
#  => => # Processing triggers for libc-bin (2.31-13+deb11u11) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
#  => => # done.
# [+] Building 16.6s (5/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  11.0s
#  => => # Processing triggers for libc-bin (2.31-13+deb11u11) ...
#  => => # Processing triggers for ca-certificates (20210119) ...
#  => => # Updating certificates in /etc/ssl/certs...
#  => => # 0 added, 0 removed; done.
#  => => # Running hooks in /etc/ca-certificates/update.d...
#  => => # done.
# [+] Building 16.7s (6/6)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  11.1s
#
#
#
#
#
#
# [+] Building 16.9s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  11.1s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 16.9s (6/7)                                   docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  11.1s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 17.0s (7/7) FINISHED                          docker:desktop-linux
#  => [internal] load build definition from my_dockerfile                    0.0s
#  => => transferring dockerfile: 1.03kB                                     0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    2.0s
#  => [auth] library/debian:pull token for registry-1.docker.io              0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  3.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => => sha256:f312f4505396ce9b46cadc2455379a400106a0ac3d3 1.48kB / 1.48kB  0.0s
#  => => sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdb 30.08MB / 30.08MB  2.5s
#  => => sha256:3f9e53602537cc817d96f0ebb131a39bdb16fa8b4221376 984B / 984B  0.0s
#  => => sha256:feff26a80167d05e2fab5f28f01ea9bb1da5d0104a14e35 529B / 529B  0.0s
#  => => extracting sha256:2245c7c084558dcf55e2bad9579c63dfdbd831cdbed2e063  1.0s
#  => [2/2] RUN apt-get update && apt-get install -y curl cowsay && apt-ge  11.1s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
#  => => writing image sha256:f4798f6b5fbf3f9f79aab5b09b9a7842fc0008372c370  0.0s
#  => => naming to docker.io/library/cowsay_image                            0.0s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/ze2ysdam167l333lv93sfmf17\docker-desktop://dashboard/build/desktop-linux/desktop-linux/ze2ysdam167l333lv93sfmf17]8;;\
#
#  2 warnings found (use docker --debug to expand):
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 5)
#  - LegacyKeyValueFormat: "LABEL key=value" should be used instead of legacy "LABEL key value" format (line 6)
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview

# %%
# make sure that the image has been built
# !docker images
# Out:
# REPOSITORY                                                 TAG                        IMAGE ID       CREATED          SIZE
# cowsay_image                                               latest                     f4798f6b5fbf   37 seconds ago   144MB
# community.wave.seqera.io/library/fastqc                    0.12.1--d3caca66b4f3d3b0   0685c8e726ea   3 months ago     925MB
# fastqc-image                                               latest                     0685c8e726ea   3 months ago     925MB
# quay.io/biocontainers/r-shinyngs                           1.8.8--r43hdfd78af_0       3ae022b36dce   5 months ago     1.34GB
# quay.io/biocontainers/atlas-gene-annotation-manipulation   1.1.1--hdfd78af_0          db9ec43ce403   5 months ago     1.25GB
# docker/welcome-to-docker                                   latest                     648f93a1ba7d   11 months ago    19MB
# hello-world                                                latest                     ee301c921b8a   17 months ago    9.14kB
# quay.io/nf-core/ubuntu                                     20.04                      88bd68917189   17 months ago    72.8MB
# quay.io/biocontainers/pandas                               1.5.2                      f82af9c4f9b8   19 months ago    342MB
# quay.io/biocontainers/gsea                                 4.3.2--hdfd78af_0          6feabbb8b995   22 months ago    546MB
# quay.io/biocontainers/r-base                               4.2.1                      8932c551c68b   23 months ago    825MB
# quay.io/biocontainers/bioconductor-deseq2                  1.34.0--r41hc247a5b_3      375cfc132ace   24 months ago    1.14GB
# quay.io/biocontainers/p7zip                                16.02                      64926fee1967   2 years ago      32.5MB
# quay.io/biocontainers/python                               3.9--1                     34c2b9e3810c   3 years ago      191MB
# quay.io/biocontainers/gawk                                 5.1.0                      1f25a9f620a3   4 years ago      38.6MB
# quay.io/biocontainers/wget                                 1.20.1                     ec9602293ac3   5 years ago      86.3MB

# %%
# run the docker file 
# !docker run --rm cowsay_image cowsay "mooo!"
# Out:
#  _______
# < mooo! >
#  -------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image

# %%
# build the image
# !docker build -t salmon_image -f salmon_docker .
# Out:
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 922B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 922B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 922B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (1/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 922B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.6s (2/2)                                    docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 922B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.7s (7/7) FINISHED                           docker:desktop-linux
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 922B                                       0.0s
#  => WARN: FromPlatformFlagConstDisallowed: FROM --platform flag should no  0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:3f9e53602537  0.0s
#  => CACHED [2/3] RUN apt-get update &&     apt-get install -y curl tar &&  0.0s
#  => CACHED [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releas  0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:f4989e50aa2a0a136e8e814226c3a349e9701b53ea9e9  0.0s
#  => => naming to docker.io/library/salmon_image                            0.0s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/m56zkg7a7wz31jrx7tjp8gkwy\docker-desktop://dashboard/build/desktop-linux/desktop-linux/m56zkg7a7wz31jrx7tjp8gkwy]8;;\
#
#  1 warning found (use docker --debug to expand):
#  - FromPlatformFlagConstDisallowed: FROM --platform flag should not use constant value "linux/amd64" (line 2)
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview

# %%
# run the docker image to give out the version of salmon

# !docker run --rm salmon_image salmon --version
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# salmon 1.5.2

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?

# %%
# !docker pull combinelab/salmon:latest
# Out:
# latest: Pulling from combinelab/salmon
#
# 7f213c76: Pulling fs layer
# 1ed9ab84: Pulling fs layer
# 0bdd40c3: Pulling fs layer
# 893c1bc1: Pulling fs layer
# 9485d7ab: Pull complete  185B/185B2MBBDigest: sha256:cefd8bb0b2ed9b07f22b5f0fc317ddda540e5b0dc00810d1ff0d92fee5d80370
# Status: Downloaded newer image for combinelab/salmon:latest
# docker.io/combinelab/salmon:latest
#
# What's next:
#     View a summary of image vulnerabilities and recommendations → docker scout quickview combinelab/salmon:latest

# %%
# !docker run --rm combinelab/salmon salmon --version
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
# salmon 1.10.3

# %% [markdown]
# It is not necessary to write a docker image yourself, since they can be found on Dockerhub or Seqera.
# BioContainers also hosts pre-built containers for many different bioinformatics tools/workflows, which can be directly pulled as images. The containers are pre-configured with all the necessary dependencies, so that you don't need to set up the environment yourself. This also makes sure that workflows run consistently across different environments. BioContainers focuses specifically on bioinformatics tools.
