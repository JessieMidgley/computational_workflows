# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# A community-based platform that hosts a set of curated Nextflow pipelines for various types of analyses.

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# 112 pipelines are currently available (66 are released).

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# Yes, there are also pipelines for economics and astronomy.

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# It is an automated process consisting of multiple organized steps, where the output from one step is the input to the next. We use them to automate a process and allow multiple people to use the same workflow and obtain the same results.

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# To ensure reproducibility and that the same pipeline always yields the same result, regardless of OS, user, etc. It also ensures that the pipelines work correctly and without errors. The comprehensive documentations helps users run to easily run the pipeline with the correct inputs/commands.

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# Processes, channels connecting the processes, and (sub)workflows of one or more processes make up the pipelines.
# Pipelines have clear documentation, softwares are packaged, and have stable releases to ensure reproducibility.

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes:

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd


# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!
# Out:
# /Users/Jessie/PycharmProjects/comp_workflows/day1

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)


# !nextflow run nf-core/differentialabundance -profile test,docker --outdir work/results -c config_cou.config -r 1.5.0
# Out:
#  N E X T F L O W   ~  version 24.04.4
#
# Launching `https://github.com/nf-core/differentialabundance` [scruffy_banach] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : scruffy_banach
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/Jessie/PycharmProjects/comp_workflows/day1
#   workDir                     : /Users/Jessie/PycharmProjects/comp_workflows/day1/work
#   projectDir                  : /Users/Jessie/.nextflow/assets/nf-core/differentialabundance
#   userName                    : Jessie
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : work/results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 0 of 1
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (1)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# Staging foreign file: https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# executor >  local (2)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (3)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 0 of 1
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (4)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS | 0 of 2
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 0 of 1
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 0 of 2
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (5)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 0 of 2
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (6)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 0 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (7)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (8)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 0 of 1
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (9)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 0 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (10)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 1 of 2
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 1
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 1
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (11)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT | 0 of 1
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 0 of 1
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (12)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 0 of 1
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (13)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE | 0 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 0 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [59/2dd06b] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (14)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [59/2dd06b] NFC…DANCE:FILTER_DIFFTABLE (1) | 0 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [59/2dd06b] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (15)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [59/2dd06b] NFC…DANCE:FILTER_DIFFTABLE (1) | 1 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 1 of 2
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (16)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 1 of 2
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (17)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [e2/abbcb1] NFC…Cherry_hND6_sample_number) | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (18)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [e2/abbcb1] NFC…Cherry_hND6_sample_number) | 0 of 2
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (19)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [e2/abbcb1] NFC…Cherry_hND6_sample_number) | 1 of 3, failed: 1, retries: 1
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
# [e2/abbcb1] NOTE: Process `NFCORE_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:GSEA_GSEA (treatment_mCherry_hND6_sample_number)` terminated with an error exit status (137) -- Execution is retried (1)
#
# executor >  local (20)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 1 of 3, failed: 1, retries: 1
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (20)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [cd/50a35d] NFC… (treatment_mCherry_hND6_) | 2 of 3, failed: 1, retries: 1
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
#
# executor >  local (20)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 3 of 3, failed: 1, retries: 1 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (21)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 3 of 3, failed: 1, retries: 1 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 0 of 1
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (22)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 3 of 3, failed: 1, retries: 1 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (22)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 3 of 3, failed: 1, retries: 1 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 0 of 1
#
# executor >  local (22)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 3 of 3, failed: 1, retries: 1 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
#
# executor >  local (22)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1 ✔
# [69/a3e394] NFC…, target:hND6, blocking:]) | 2 of 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1 ✔
# [6b/73b1da] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 3 of 3, failed: 1, retries: 1 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1 ✔
# [11/df57ec] NFC… (treatment_mCherry_hND6_) | 2 of 2 ✔
# [13/9bf262] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1 ✔
# Completed at: 20-Oct-2024 18:57:03
# Duration    : 27m 2s
# CPU hours   : 1.7 (76,7% failed)
# Succeeded   : 21
# Failed      : 1

# %%
# repeat the run. What did change?

# %% [markdown]
# The run started from scratch again and new subdirectories were created in the work folder for each process. The run took a similar amount of time to finish, since all processes had to be re-run from scratch. The results themselves were identical to the first run. New subdirectories were created in the work directory.

# %%
# now set -resume to the command. What did change?
# !nextflow run nf-core/differentialabundance -profile test,docker --outdir work/results -c config_cou.config -r 1.5.0 -resume
# Out:
#  N E X T F L O W   ~  version 24.04.4
#
# Launching `https://github.com/nf-core/differentialabundance` [infallible_wing] DSL2 - revision: 3dd360fed0 [1.5.0]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : 1.5.0
#   runName                     : infallible_wing
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /Users/Jessie/PycharmProjects/comp_workflows/day1
#   workDir                     : /Users/Jessie/PycharmProjects/comp_workflows/day1/work
#   projectDir                  : /Users/Jessie/.nextflow/assets/nf-core/differentialabundance
#   userName                    : Jessie
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : work/results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
#
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…TIALABUNDANCE:GTF_TO_TABLE -
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:VALIDATOR -
# [-        ] NFC…NDANCE:CUSTOM_MATRIXFILTER -
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEACLS -
# [-        ] NFC…DANCE:TABULAR_TO_GSEA_CHIP -
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [-        ] NFC…NTIALABUNDANCE:DESEQ2_NORM -
# [-        ] NFC…NDANCE:DESEQ2_DIFFERENTIAL -
# [-        ] NFC…ABUNDANCE:FILTER_DIFFTABLE -
# [-        ] NFC…CE:CUSTOM_TABULARTOGSEAGCT -
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [-        ] NFC…ABUNDANCE:PLOT_EXPLORATORY -
# [-        ] NFC…BUNDANCE:PLOT_DIFFERENTIAL -
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP -
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [-        ] NFC…RENTIALABUNDANCE:GSEA_GSEA -
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [-        ] NFC…TIALABUNDANCE:SHINYNGS_APP | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [cf/18142d] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [-        ] NFC…BUNDANCE:RMARKDOWNNOTEBOOK -
# [-        ] NFC…UNDANCE:MAKE_REPORT_BUNDLE -
#
# executor >  local (1)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [cf/18142d] NFC…E:SHINYNGS_APP (SRP254919) | 0 of 1
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [cf/18142d] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
#
# executor >  local (1)
# [51/fa20b0] NFC…musculus.GRCm38.81.gtf.gz) | 1 of 1, cached: 1 ✔
# [68/cbd02f] NFC…TF_TO_TABLE (Mus_musculus) | 1 of 1, cached: 1 ✔
# [6a/e4683c] NFC…SRP254919.samplesheet.csv) | 1 of 1, cached: 1 ✔
# [3f/8854af] NFC…RIXFILTER ([id:SRP254919]) | 1 of 1, cached: 1 ✔
# [0b/51a2b2] NFC…, target:hND6, blocking:]) | 1 of 1, cached: 1 ✔
# [b3/682d92] NFC…, blocking:sample_number]) | 2 of 2, cached: 2 ✔
# [e4/d297fb] NFC…DANCE:FILTER_DIFFTABLE (2) | 2 of 2, cached: 2 ✔
# [cb/86057e] NFC… (treatment_mCherry_hND6_) | 1 of 1, cached: 1 ✔
# [59/a4c5d4] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [d4/33047f] NFC…E:TABULAR_TO_GSEA_CHIP (1) | 1 of 1, cached: 1 ✔
# [f4/3c8027] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [4c/6ee6d0] NFC…OT_EXPLORATORY (treatment) | 1 of 1, cached: 1 ✔
# [c0/bf95a3] NFC…Cherry_hND6_sample_number) | 2 of 2, cached: 2 ✔
# [cf/18142d] NFC…E:SHINYNGS_APP (SRP254919) | 1 of 1 ✔
# [f2/d2573f] NFC…RKDOWNNOTEBOOK (SRP254919) | 1 of 1, cached: 1 ✔
# [a7/000323] NFC…_REPORT_BUNDLE (SRP254919) | 1 of 1, cached: 1 ✔
# Completed at: 20-Oct-2024 19:01:16
# Duration    : 1m 26s
# CPU hours   : 0.4 (94,5% cached)
# Succeeded   : 1
# Cached      : 20

# %% [markdown]
# Cached files from the previous run were used. Since each individual process did not need to be re-run, the pipeline ran much faster overall (1min 26s) and no new subdirectories were created in the work folder. The results remain identical.

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %% [markdown]
# From the first and second run, we have a lot of subdirectories containing the outputs from individual processes. There are also 2 stage directories. A log file for each run is also created. In the tmp directory there are samplesheets for the samples.

# %%
# delete the work directory and run the pipeline again using -resume. What did change?

# %% [markdown]
# What changed?
# Since there are no cached files this time, the run starts from scratch and performs each process again, producing a new work directory.

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# It compares observations in data matrices to generate differential statistics, for example when comparing differential expression between samples under different treatment conditions. It reveals if there is a statistically significant difference in gene expression between samples.

# %% [markdown]
# Give the most important plots from the report:

# %% [markdown]
# ![title](./work/results/plots/differential/treatment_mCherry_hND6_/png/volcano.png)

# %% [markdown]
# ![title](./work/results/plots/exploratory/treatment/png/density.png)

# %% [markdown]
# ![title](./work/results/plots/exploratory/treatment/png/boxplot.png)

# %% [markdown]
# ![title](./work/results/plots/exploratory/treatment/png/pca3d.png)

# %% [markdown]
# ![title](./work/results/plots/exploratory/treatment/png/pca2d.png)
